# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
#aj.plot(kind='bar',y='PtID',x='index', legend=True,title="Glucose level vs Patients" )
pk= aj[['PtID','Gl']].groupby('PtID').mean().reset_index()


#aj.plot( legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency",style='o',ms=1)
pk.plot(kind='barh', x='PtID',y='Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
#plot1.plot(kind='box',x='PtID', y = 'Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
plt.show()

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(nrows=2, ncols=2)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
#aj.plot(kind='bar',y='PtID',x='index', legend=True,title="Glucose level vs Patients" )
#pk= aj[['PtID','Gl']].groupby('PtID').mean().reset_index()

t1 = ['PtID','Gl']
color1 = ['b','r']
p = 0
for k in t1:
#aj.plot( legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency",style='o',ms=1)
    aj.plot(kind='scatter', x='index',y=k,legend=True,title=f"Scatter Plot" ,color=color1[p],xlabel="index",ylabel="Frequency")
    p +=1

#plot1.plot(kind='box',x='PtID', y = 'Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
plt.show()

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
#aj.plot(kind='bar',y='PtID',x='index', legend=True,title="Glucose level vs Patients" )
#pk= aj[['PtID','Gl']].groupby('PtID').mean().reset_index()

list = ['Gl','index']
for k in list:
#aj.plot( legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency",style='o',ms=1)
    aj.plot(kind='scatter', x='PtID',y=k,ax=plot1,legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
#plot1.plot(kind='box',x='PtID', y = 'Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
plt.show()

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
# aj.plot(kind='hist',y='Gl',x='index', legend=True,title="Glucose level vs Patients" )

#df['PtID'].plot(kind='pie', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 16
#      12 aj = df.reset_index()
#      13 # aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
#      14 # aj.plot(kind='hist',y='Gl',x='index', legend=True,title="Glucose level vs Patients" )
# ---> 16 df['PtID'].plot(kind='pie', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency")
#      17 plt.show()
#
# File c:\Users\amarp\.conda\envs\visualization-app\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# ...

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')
data = [['tom', 10,'m'], ['nick', 15,'f'], ['juli', 14,'f'],['nick',15,'f']]



# Create the pandas DataFrame
df = pd.DataFrame(data, columns=['name', 'age','sex'])
select = [2]
lis = []
for i in select:
    lis.append(df.columns[i])


print(df[lis])

# print dataframe.
#print(df.groupby('sex').sum())
# Out:
#      age
# sex
# f      3
# m      1
#    name  age sex
# 0   tom   10   m
# 1  nick   15   f
# 2  juli   14   f
# 3  nick   15   f

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
#aj.plot(kind='bar',y='PtID',x='index', legend=True,title="Glucose level vs Patients" )
#pk= aj[['PtID','Gl']].groupby('PtID').mean().reset_index()

list1 = ['Gl','index']
for k in list1:
#aj.plot( legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency",style='o',ms=1)
    plot1.scatter(data=aj,x='index',y=k,color='r')
    
#plot1.plot(kind='box',x='PtID', y = 'Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
plot1.plot()
plt.show()

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import numpy as np
import pandas as pd
df = pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
# aj.plot(kind='hist',y='Gl',x='index', legend=True,title="Glucose level vs Patients" )

df['A'].plot(kind='line', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency")
plt.show()
