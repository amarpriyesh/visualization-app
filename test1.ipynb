# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
#aj.plot(kind='bar',y='PtID',x='index', legend=True,title="Glucose level vs Patients" )
pk= aj[['PtID','Gl']].groupby('PtID').mean().reset_index()


#aj.plot( legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency",style='o',ms=1)
pk.plot(kind='barh', x='PtID',y='Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
#plot1.plot(kind='box',x='PtID', y = 'Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
plt.show()

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(nrows=2, ncols=2)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
#aj.plot(kind='bar',y='PtID',x='index', legend=True,title="Glucose level vs Patients" )
#pk= aj[['PtID','Gl']].groupby('PtID').mean().reset_index()

t1 = ['PtID','Gl']
color1 = ['b','r']
p = 0
for k in t1:
#aj.plot( legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency",style='o',ms=1)
    aj.plot(kind='scatter', x='index',ax=ax1,y=k,legend=True,title=f"Scatter Plot" ,color=color1[p],xlabel="index",ylabel="Frequency")
    p +=1

#plot1.plot(kind='box',x='PtID', y = 'Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
plt.show()

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')
aj = df.reset_index()

fig, axs = plt.subplots(nrows=3, ncols=3, figsize=(15, 12))
plt.subplots_adjust(hspace=0.5)
fig.suptitle("Daily closing prices", fontsize=18, y=0.95)

# loop through tickers and axes
for ax in axs.ravel():
    # filter df for ticker and plot on specified axes
    
    aj.plot(kind='scatter', x='index',ax=ax,y='Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")

    # chart formatting
    ax.set_title('kk')
   
    ax.set_xlabel("")

plt.show()

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
#aj.plot(kind='bar',y='PtID',x='index', legend=True,title="Glucose level vs Patients" )
#pk= aj[['PtID','Gl']].groupby('PtID').mean().reset_index()

list = ['Gl','index']
for k in list:
#aj.plot( legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency",style='o',ms=1)
    aj.plot(kind='scatter', x='PtID',y=k,ax=plot1,legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
#plot1.plot(kind='box',x='PtID', y = 'Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=[[1,'car',20,6],[2,'car',40,4],[3,'bus',50,8],[4,'bike',10,2]]
df = pd.DataFrame(df, columns=['id','vechle', 'num','wheels'])

df1 = pd.DataFrame({'id': ['A01', 'A02', 'A03', 'A04'],
                    'Name': ['ABC', 'PQR', 'DEF', 'GHI']})

df1.set_index('id', inplace=True, drop=True)
# Second DataFrame
df2 = pd.DataFrame({'id': ['A04', 'B06', 'B07', 'B08'],
                    'Name': ['XYZ', 'TUV', 'MNO', 'JKL']})
df2.set_index('id', inplace=True, drop=True)



df_union= pd.concat([df1, df2]).drop_duplicates(keep='first')





print(df_union)
  





# kd = df.groupby('type').sum('num').sort_index(ascending=True)



# print(kd)
# kd.reset_index().plot(kind='box',x ='type',xlabel='sss',title="Hey",legend=True,)
# plt.show()
# Out:
#     Name
# id
# A01  ABC
# A02  PQR
# A03  DEF
# A04  GHI
# A04  XYZ
# B06  TUV
# B07  MNO
# B08  JKL

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df

ad = aj.groupby(['PtID']).sum(['Gl'])



# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
# aj.plot(kind='hist',y='Gl',x='index', legend=True,title="Glucose level vs Patients" )
print(ad)
ad.plot(kind='pie',y='Gl',subplots=True,legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency")
#ad.plot(kind='pie',y='RecID',subplots=True,legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency")
plt.show()
# Out:
#             RecID       Gl
# PtID
# 2       525006212  1407022
# 4      1594678238  2281283
# 5      9646263276  3617405
# 6      4337099306  2676395
# 7      4168992789  1428530
# 8      2678623899  1334145
# 9      6656729195  2354666
# 10     8271313697  3635910
# 11     2155557174  1353212
# 12     4123862599  2732597
# 13     2534474859  1636955
# 14     2811386896  1506206
# 15     1596312644  1230884
# 17     7670278742  3901953
# 18     3171603991  2840072
# 19     5862816189  2973628
# 20     3786146362  2264428
# 21     1748717447  1616012
# 22     6527791362  3445221
# 23     5530458461  3778574
# 25     7477127063  3322086
# 26     5881966215  3324337
# 28     9395041657  3190890
# 29     9471227696  3583205
# 30     7099055279  3271047
# 31     4073415507   525548
# 32    26314308119  4301911
# 33     7415434294  1303273
# 35    17494876980  2322455
# 36     6686652599   975211
# 37     9521223840  1676545
# 38    18056218653  3500540
# 39    11949073874  1944815
# 40     7288444448  1056756
# 41    22789283301  4171866
# 43     9888510062  1203540
# 44    19087581425  2884792
# 47    19235616770  3511247
# 50    18203563439  3176215
# 51     8442301940  1186035
# 52     8170596524  1341396
# 53     7350949766  1287640
# 54    11136174867  1897420
# 57     9866382078  2131281
# 58    16294223571  2580701
# 59    14275151540  2346487
# 60     7306839144  1169996
# 62     8470298091  1162525

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')
data = [['tom', 10,'m'], ['nick', 15,'f'], ['juli', 14,'f'],['nick',15,'f']]



# Create the pandas DataFrame
df = pd.DataFrame(data, columns=['name', 'age','sex'])
select = [2]
lis = []
for i in select:
    lis.append(df.columns[i])


print(df[lis])

# print dataframe.
#print(df.groupby('sex').sum())
# Out:
#      age
# sex
# f      3
# m      1
#    name  age sex
# 0   tom   10   m
# 1  nick   15   f
# 2  juli   14   f
# 3  nick   15   f

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
df = pd.read_csv('Glucose.csv')

sales  = ["cars","bikes"]
# plt.bar(x=sales,height=number_of_sales)
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
#aj.plot(kind='bar',y='PtID',x='index', legend=True,title="Glucose level vs Patients" )
#pk= aj[['PtID','Gl']].groupby('PtID').mean().reset_index()

list1 = ['Gl','index']
for k in list1:
#aj.plot( legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency",style='o',ms=1)
    plot1.scatter(data=aj,x='index',y=k,color='r')
    
#plot1.plot(kind='box',x='PtID', y = 'Gl',legend=True,title=f"Scatter Plot" ,color='r',xlabel="index",ylabel="Frequency")
plot1.plot()
plt.show()

# %%
from matplotlib.figure import Figure
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import numpy as np
import pandas as pd
df = pd.DataFrame(np.random.randint(0,100,size=(100, 4)), columns=list('ABCD'))
fig = Figure(figsize = (5, 5),
                 dpi = 80)
plot1 = fig.add_subplot(111)
aj = df.reset_index()
# aj.plot(kind='scatter',y='Gl',x='index', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="GL")
# aj.plot(kind='hist',y='Gl',x='index', legend=True,title="Glucose level vs Patients" )

df['A'].plot(kind='line', legend=True,title=f"Scatter Plot" ,xlabel="index",ylabel="Frequency")
plt.show()
